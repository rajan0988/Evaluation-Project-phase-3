# %%
#imorting libraries

import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")


df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
# No of Rows: 1000
# No of Columns: 40
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Sort columns by datatypes
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year'], float64: ['policy_annual_premium', '_c39'], object: ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']}

# %%
df.duplicated('policy_number').sum()
# Out:
# 0

# %%
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
df.isin(['?']).sum().any()
# Out:
# True

# %%
df=df.replace('?',np.NaN)

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                              Missing Values  % Missing data
# _c39                                   1000           100.0
# property_damage                         360            36.0
# police_report_available                 343            34.3
# collision_type                          178            17.8
# bodily_injuries                           0             0.0
# incident_state                            0             0.0
# incident_city                             0             0.0
# incident_location                         0             0.0
# incident_hour_of_the_day                  0             0.0
# number_of_vehicles_involved               0             0.0
# fraud_reported                            0             0.0
# auto_year                                 0             0.0
# auto_model                                0             0.0
# authorities_contacted                     0             0.0
# total_claim_amount                        0             0.0
# injury_claim                              0             0.0
# property_claim                            0             0.0
# vehicle_claim                             0             0.0
# auto_make                                 0             0.0
# witnesses                                 0             0.0
# months_as_customer                        0             0.0
# age                                       0             0.0
# insured_zip                               0             0.0
# policy_number                             0             0.0
# policy_bind_date                          0             0.0
# policy_state                              0             0.0
# policy_csl                                0             0.0
# policy_deductable                         0             0.0
# policy_annual_premium                     0             0.0
# umbrella_limit                            0             0.0
# insured_sex                               0             0.0
# incident_type                             0             0.0
# insured_education_level                   0             0.0
# insured_occupation                        0             0.0
# insured_hobbies                           0             0.0
# insured_relationship                      0             0.0
# capital-gains                             0             0.0
# capital-loss                              0             0.0
# incident_date                             0             0.0
# incident_severity                         0             0.0

# %%
df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %%
# Droping unnecessary columns
df.drop(['_c39','incident_location','insured_zip','policy_number'],axis=1,inplace=True)

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="gist_earth")
plt.show()

# %%
# Spliting and extracting policy_csl at '/'
df['CSL_Personal']=df.policy_csl.str.split('/',expand=True)[0]
df['CSL_Accidental']=df.policy_csl.str.split('/',expand=True)[1]

# %%
# Now we can drop policy_csl column 
df.drop("policy_csl",axis=1,inplace=True)

# %%
# Converting Date columns from object type into datetime data type
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
# Extracting Day, Month and Year column from policy_bind_date
df['policy_bind_day'] = df['policy_bind_date'].dt.day
df['policy_bind_month'] = df['policy_bind_date'].dt.month
df['policy_bind_year'] = df['policy_bind_date'].dt.year

# Extracting Day, Month and Year column from incident_date
df['incident_day'] = df['incident_date'].dt.day
df['incident_month'] = df['incident_date'].dt.month
df['incident_year'] = df['incident_date'].dt.year

# %%
# Since Extraction is done now we can Drop policy_bind_date and incident_date columns
df.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)

# %%
# Incident year for all data is 2015 so we gone drop it.
df.drop(['incident_year'],axis=1,inplace=True)

# %%
# Lets extract age of the vehicle from auto_year by subtracting it from the year 2018
df['Automobile_Age']=2015 - df['auto_year']
# Droping auto year column
df.drop("auto_year",axis=1,inplace=True)

# %%
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age'], float64: ['policy_annual_premium'], object: ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']}

# %%
#statistical analysis 

df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
df.isin(['?']).sum().any()
# Out:
# False

# %%
df=df.replace('?',np.NaN)

# %%
#missing value check 

#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                              Missing Values  % Missing data
# months_as_customer                        0             0.0
# age                                       0             0.0
# bodily_injuries                           0             0.0
# witnesses                                 0             0.0
# police_report_available                   0             0.0
# total_claim_amount                        0             0.0
# injury_claim                              0             0.0
# property_claim                            0             0.0
# vehicle_claim                             0             0.0
# auto_make                                 0             0.0
# auto_model                                0             0.0
# fraud_reported                            0             0.0
# CSL_Personal                              0             0.0
# CSL_Accidental                            0             0.0
# policy_bind_day                           0             0.0
# policy_bind_month                         0             0.0
# policy_bind_year                          0             0.0
# incident_day                              0             0.0
# incident_month                            0             0.0
# property_damage                           0             0.0
# number_of_vehicles_involved               0             0.0
# incident_hour_of_the_day                  0             0.0
# insured_hobbies                           0             0.0
# policy_state                              0             0.0
# policy_deductable                         0             0.0
# policy_annual_premium                     0             0.0
# umbrella_limit                            0             0.0
# insured_sex                               0             0.0
# insured_education_level                   0             0.0
# insured_occupation                        0             0.0
# insured_relationship                      0             0.0
# incident_city                             0             0.0
# capital-gains                             0             0.0
# capital-loss                              0             0.0
# incident_type                             0             0.0
# collision_type                            0             0.0
# incident_severity                         0             0.0
# authorities_contacted                     0             0.0
# incident_state                            0             0.0
# Automobile_Age                            0             0.0

# %%
#missing value imputation

df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="gist_earth")
plt.show()

# %%
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age'], float64: ['policy_annual_premium'], object: ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']}

# %%
#statistical matrix

df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_f59e0_row0_col0, #T_f59e0_row0_col2, #T_f59e0_row1_col0, #T_f59e0_row1_col2, #T_f59e0_row2_col0, #T_f59e0_row2_col2, #T_f59e0_row3_col0, #T_f59e0_row3_col2, #T_f59e0_row4_col0, #T_f59e0_row5_col0, #T_f59e0_row6_col0, #T_f59e0_row6_col1, #T_f59e0_row6_col5, #T_f59e0_row7_col0, #T_f59e0_row7_col2, #T_f59e0_row8_col0, #T_f59e0_row8_col2, #T_f59e0_row9_col0, #T_f59e0_row9_col2, #T_f59e0_row10_col0, #T_f59e0_row10_col2, #T_f59e0_row11_col0, #T_f59e0_row12_col0, #T_f59e0_row12_col2, #T_f59e0_row13_col0, #T_f59e0_row13_col2, #T_f59e0_row14_col0, #T_f59e0_row15_col0, #T_f59e0_row15_col2, #T_f59e0_row16_col0, #T_f59e0_row16_col2, #T_f59e0_row17_col0, #T_f59e0_row17_col2, #T_f59e0_row18_col0, #T_f59e0_row18_col2, #T_f59e0_row19_col0, #T_f59e0_row19_col2, #T_f59e0_row20_col0, #T_f59e0_row20_col2 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_f59e0_row0_col1, #T_f59e0_row1_col1, #T_f59e0_row2_col1, #T_f59e0_row3_col1, #T_f59e0_row7_col1, #T_f59e0_row8_col1, #T_f59e0_row9_col1, #T_f59e0_row10_col1, #T_f59e0_row15_col1, #T_f59e0_row16_col1, #T_f59e0_row17_col1, #T_f59e0_row18_col1, #T_f59e0_row19_col1, #T_f59e0_row20_col1 {
#   background-color: #fff3ef;
#   color: #000000;
# }
# #T_f59e0_row0_col5, #T_f59e0_row1_col5, #T_f59e0_row4_col5, #T_f59e0_row5_col5, #T_f59e0_row7_col5, #T_f59e0_row8_col5, #T_f59e0_row9_col5, #T_f59e0_row10_col5, #T_f59e0_row15_col5, #T_f59e0_row16_col5, #T_f59e0_row18_col5, #T_f59e0_row19_col5, #T_f59e0_row20_col5 {
#   background-color: #fbbabd;
#   color: #000000;
# }
# #T_f59e0_row2_col5 {
#   background-color: #fbb6bc;
#   color: #000000;
# }
# #T_f59e0_row3_col5 {
#   background-color: #fbb5bb;
#   color: #000000;
# }
# #T_f59e0_row4_col1, #T_f59e0_row4_col2, #T_f59e0_row11_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_f59e0_row5_col1 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_f59e0_row5_col2, #T_f59e0_row6_col2 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_f59e0_row11_col1 {
#   background-color: #feeae7;
#   color: #000000;
# }
# #T_f59e0_row11_col2, #T_f59e0_row14_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_f59e0_row12_col1, #T_f59e0_row13_col1 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_f59e0_row12_col5, #T_f59e0_row13_col5 {
#   background-color: #faa1b6;
#   color: #000000;
# }
# #T_f59e0_row14_col1 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_f59e0_row14_col5 {
#   background-color: #98017b;
#   color: #f1f1f1;
# }
# #T_f59e0_row17_col5 {
#   background-color: #fbb3bb;
#   color: #000000;
# }
# </style>
# <table id="T_f59e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f59e0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f59e0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f59e0_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f59e0_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f59e0_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f59e0_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f59e0_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f59e0_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f59e0_level0_row0" class="row_heading level0 row0" >months_as_customer</th>
#       <td id="T_f59e0_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_f59e0_row0_col1" class="data row0 col1" >203.954000</td>
#       <td id="T_f59e0_row0_col2" class="data row0 col2" >115.113174</td>
#       <td id="T_f59e0_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f59e0_row0_col4" class="data row0 col4" >115.750000</td>
#       <td id="T_f59e0_row0_col5" class="data row0 col5" >199.500000</td>
#       <td id="T_f59e0_row0_col6" class="data row0 col6" >276.250000</td>
#       <td id="T_f59e0_row0_col7" class="data row0 col7" >479.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_f59e0_row1_col0" class="data row1 col0" >1000.000000</td>
#       <td id="T_f59e0_row1_col1" class="data row1 col1" >38.948000</td>
#       <td id="T_f59e0_row1_col2" class="data row1 col2" >9.140287</td>
#       <td id="T_f59e0_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_f59e0_row1_col4" class="data row1 col4" >32.000000</td>
#       <td id="T_f59e0_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_f59e0_row1_col6" class="data row1 col6" >44.000000</td>
#       <td id="T_f59e0_row1_col7" class="data row1 col7" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row2" class="row_heading level0 row2" >policy_deductable</th>
#       <td id="T_f59e0_row2_col0" class="data row2 col0" >1000.000000</td>
#       <td id="T_f59e0_row2_col1" class="data row2 col1" >1136.000000</td>
#       <td id="T_f59e0_row2_col2" class="data row2 col2" >611.864673</td>
#       <td id="T_f59e0_row2_col3" class="data row2 col3" >500.000000</td>
#       <td id="T_f59e0_row2_col4" class="data row2 col4" >500.000000</td>
#       <td id="T_f59e0_row2_col5" class="data row2 col5" >1000.000000</td>
#       <td id="T_f59e0_row2_col6" class="data row2 col6" >2000.000000</td>
#       <td id="T_f59e0_row2_col7" class="data row2 col7" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row3" class="row_heading level0 row3" >policy_annual_premium</th>
#       <td id="T_f59e0_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_f59e0_row3_col1" class="data row3 col1" >1256.406150</td>
#       <td id="T_f59e0_row3_col2" class="data row3 col2" >244.167395</td>
#       <td id="T_f59e0_row3_col3" class="data row3 col3" >433.330000</td>
#       <td id="T_f59e0_row3_col4" class="data row3 col4" >1089.607500</td>
#       <td id="T_f59e0_row3_col5" class="data row3 col5" >1257.200000</td>
#       <td id="T_f59e0_row3_col6" class="data row3 col6" >1415.695000</td>
#       <td id="T_f59e0_row3_col7" class="data row3 col7" >2047.590000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row4" class="row_heading level0 row4" >umbrella_limit</th>
#       <td id="T_f59e0_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_f59e0_row4_col1" class="data row4 col1" >1101000.000000</td>
#       <td id="T_f59e0_row4_col2" class="data row4 col2" >2297406.598118</td>
#       <td id="T_f59e0_row4_col3" class="data row4 col3" >-1000000.000000</td>
#       <td id="T_f59e0_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_f59e0_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_f59e0_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_f59e0_row4_col7" class="data row4 col7" >10000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row5" class="row_heading level0 row5" >capital-gains</th>
#       <td id="T_f59e0_row5_col0" class="data row5 col0" >1000.000000</td>
#       <td id="T_f59e0_row5_col1" class="data row5 col1" >25126.100000</td>
#       <td id="T_f59e0_row5_col2" class="data row5 col2" >27872.187708</td>
#       <td id="T_f59e0_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f59e0_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_f59e0_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_f59e0_row5_col6" class="data row5 col6" >51025.000000</td>
#       <td id="T_f59e0_row5_col7" class="data row5 col7" >100500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f59e0_level0_row6" class="row_heading level0 row6" >capital-loss</th>
#       <td id="T_f59e0_row6_col0" class="data row6 col0" >1000.000000</td>
#       <td id="T_f59e0_row6_col1" class="data row6 col1" >-26793.700000</td>
#       <td id="T_f59e0_row6_col2" class="data row6 col2" >28104.096686</td>
#       <td id="T_f59e0_row6_col3" class="data row6 col3" >-111100.000000</td>
#       <td id="T_f59e0_row6_col4" class="data row6 col4" >-51500.000000</td>
#       <td id="T_f59e0_row6_col5" class="data row6 col5" >-23250.000000</td>
#       <td id="T_f59e0_row6_col6" class="da

# %%
df[Category].describe().T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bce5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bce5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6bce5_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_6bce5_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_6bce5_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bce5_level0_row0" class="row_heading level0 row0" >policy_state</th>
#       <td id="T_6bce5_row0_col0" class="data row0 col0" >1000</td>
#       <td id="T_6bce5_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_6bce5_row0_col2" class="data row0 col2" >OH</td>
#       <td id="T_6bce5_row0_col3" class="data row0 col3" >352</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row1" class="row_heading level0 row1" >insured_sex</th>
#       <td id="T_6bce5_row1_col0" class="data row1 col0" >1000</td>
#       <td id="T_6bce5_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_6bce5_row1_col2" class="data row1 col2" >FEMALE</td>
#       <td id="T_6bce5_row1_col3" class="data row1 col3" >537</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row2" class="row_heading level0 row2" >insured_education_level</th>
#       <td id="T_6bce5_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_6bce5_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_6bce5_row2_col2" class="data row2 col2" >JD</td>
#       <td id="T_6bce5_row2_col3" class="data row2 col3" >161</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row3" class="row_heading level0 row3" >insured_occupation</th>
#       <td id="T_6bce5_row3_col0" class="data row3 col0" >1000</td>
#       <td id="T_6bce5_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_6bce5_row3_col2" class="data row3 col2" >machine-op-inspct</td>
#       <td id="T_6bce5_row3_col3" class="data row3 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row4" class="row_heading level0 row4" >insured_hobbies</th>
#       <td id="T_6bce5_row4_col0" class="data row4 col0" >1000</td>
#       <td id="T_6bce5_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_6bce5_row4_col2" class="data row4 col2" >reading</td>
#       <td id="T_6bce5_row4_col3" class="data row4 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row5" class="row_heading level0 row5" >insured_relationship</th>
#       <td id="T_6bce5_row5_col0" class="data row5 col0" >1000</td>
#       <td id="T_6bce5_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_6bce5_row5_col2" class="data row5 col2" >own-child</td>
#       <td id="T_6bce5_row5_col3" class="data row5 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row6" class="row_heading level0 row6" >incident_type</th>
#       <td id="T_6bce5_row6_col0" class="data row6 col0" >1000</td>
#       <td id="T_6bce5_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_6bce5_row6_col2" class="data row6 col2" >Multi-vehicle Collision</td>
#       <td id="T_6bce5_row6_col3" class="data row6 col3" >419</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row7" class="row_heading level0 row7" >collision_type</th>
#       <td id="T_6bce5_row7_col0" class="data row7 col0" >1000</td>
#       <td id="T_6bce5_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_6bce5_row7_col2" class="data row7 col2" >Rear Collision</td>
#       <td id="T_6bce5_row7_col3" class="data row7 col3" >470</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row8" class="row_heading level0 row8" >incident_severity</th>
#       <td id="T_6bce5_row8_col0" class="data row8 col0" >1000</td>
#       <td id="T_6bce5_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_6bce5_row8_col2" class="data row8 col2" >Minor Damage</td>
#       <td id="T_6bce5_row8_col3" class="data row8 col3" >354</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row9" class="row_heading level0 row9" >authorities_contacted</th>
#       <td id="T_6bce5_row9_col0" class="data row9 col0" >1000</td>
#       <td id="T_6bce5_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_6bce5_row9_col2" class="data row9 col2" >Police</td>
#       <td id="T_6bce5_row9_col3" class="data row9 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row10" class="row_heading level0 row10" >incident_state</th>
#       <td id="T_6bce5_row10_col0" class="data row10 col0" >1000</td>
#       <td id="T_6bce5_row10_col1" class="data row10 col1" >7</td>
#       <td id="T_6bce5_row10_col2" class="data row10 col2" >NY</td>
#       <td id="T_6bce5_row10_col3" class="data row10 col3" >262</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row11" class="row_heading level0 row11" >incident_city</th>
#       <td id="T_6bce5_row11_col0" class="data row11 col0" >1000</td>
#       <td id="T_6bce5_row11_col1" class="data row11 col1" >7</td>
#       <td id="T_6bce5_row11_col2" class="data row11 col2" >Springfield</td>
#       <td id="T_6bce5_row11_col3" class="data row11 col3" >157</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row12" class="row_heading level0 row12" >property_damage</th>
#       <td id="T_6bce5_row12_col0" class="data row12 col0" >1000</td>
#       <td id="T_6bce5_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_6bce5_row12_col2" class="data row12 col2" >NO</td>
#       <td id="T_6bce5_row12_col3" class="data row12 col3" >698</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row13" class="row_heading level0 row13" >police_report_available</th>
#       <td id="T_6bce5_row13_col0" class="data row13 col0" >1000</td>
#       <td id="T_6bce5_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_6bce5_row13_col2" class="data row13 col2" >NO</td>
#       <td id="T_6bce5_row13_col3" class="data row13 col3" >686</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row14" class="row_heading level0 row14" >auto_make</th>
#       <td id="T_6bce5_row14_col0" class="data row14 col0" >1000</td>
#       <td id="T_6bce5_row14_col1" class="data row14 col1" >14</td>
#       <td id="T_6bce5_row14_col2" class="data row14 col2" >Saab</td>
#       <td id="T_6bce5_row14_col3" class="data row14 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row15" class="row_heading level0 row15" >auto_model</th>
#       <td id="T_6bce5_row15_col0" class="data row15 col0" >1000</td>
#       <td id="T_6bce5_row15_col1" class="data row15 col1" >39</td>
#       <td id="T_6bce5_row15_col2" class="data row15 col2" >RAM</td>
#       <td id="T_6bce5_row15_col3" class="data row15 col3" >43</td>
#     </tr>
#     <tr>
#       <th id="T_6bce5_level0_row16" class="row_heading level0 row16" >fraud_reported</th>
#       <td id="T_6bce5_row16_col0" class="data row16 col0" >1000</td>
#       <td id="T_6bce5_row16_col1" class="data row16 col1" >2</td>
#       <td id="T_6bce5_row16_col2" class="data row16 col2" >N</td>
#       <td id="T_6bce5_row16_col3" class="data row16 col3" >753</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# policy_state
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# ====================================================================================================
# insured_sex
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64
# ====================================================================================================
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64
# ====================================================================================================
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64
# ====================================================================================================
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64
# ====================================================================================================
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64
# ====================================================================================================
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64
# ====================================================================================================
# collision_type
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64
# ====================================================================================================
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64
# ====================================================================================================
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64
# ====================================================================================================
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64
# ====================================================================================================
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64
# ====================================================================================================
# property_damage
# NO     698
# YES    302
# Name: property_damage, dtype: int64
# ====================================================================================================
# police_report_available
# NO     686
# YES    314
# Name: police_report_available, dtype: int64
# ====================================================================================================
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64
# ====================================================================================================
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64
# ====================================================================================================
# fraud_reported
# N    753
# Y    247
# Name: fraud_reported, dtype: int64
# ====================================================================================================

# %%
print('Minimum Age :',df.age.min(),'Years')
print('Maximum Age :',df.age.max(),'Years')
print('Average Age :',df.age.mean(),'Years')
# Out:
# Minimum Age : 19 Years
# Maximum Age : 64 Years
# Average Age : 38.948 Years

# %%
plt.figure(figsize=(7,6))
sns.histplot(df.age, kde=True, color='b')
plt.xlabel('Age',fontsize=16)
plt.title('Age Distribution', fontsize=18,fontweight ='bold')
plt.show()

# %%
# Spliting age in different age range
df['age_bins'] = pd.cut(df.age, bins = [0, 10, 20, 30, 40, 50, 60, 70], 
                          include_lowest = True, labels = ['0-10','11-20','21-30','31-40', '41-50', '51-60', '61-70'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df.age_bins, hue=df.fraud_reported)
plt.xlabel('Age',fontsize=18,fontweight ='bold')
plt.title('Age Distribution Vs Fraud Cases', fontsize=20,fontweight ='bold')
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['policy_state'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder State Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['policy_state'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Statewise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" State ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_sex'].value_counts().plot.pie(explode=[0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Gender Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_sex'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Genderwise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Gender ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_education_level'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Education_level Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_education_level'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases vs Policy-holder Education_level ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Education_level ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,7)
table = pd.crosstab(df['incident_type'], df['fraud_reported'])
table.plot(kind = 'bar')
plt.title('Fraud cases As per Incident Type',fontsize=20,fontweight ='bold')
plt.xlabel('Different Incidents', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
#exploration of different cases 

plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['collision_type'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['collision_type'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases in different Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('coolwarm')
table = pd.crosstab(df['incident_type'], df['collision_type'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True)
plt.title(' Incident Type VS Collision Type',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['incident_severity'].value_counts().plot.pie(explode=[0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Severity of Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['incident_severity'], df['collision_type'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Incident Severity vs Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['incident_type'], df['incident_severity']).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fd835_row0_col0, #T_fd835_row0_col2, #T_fd835_row2_col1, #T_fd835_row3_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_fd835_row0_col1 {
#   background-color: #108866;
#   color: #f1f1f1;
# }
# #T_fd835_row0_col3, #T_fd835_row1_col0, #T_fd835_row1_col1, #T_fd835_row1_col2, #T_fd835_row2_col3, #T_fd835_row3_col0, #T_fd835_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fd835_row1_col3 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_fd835_row2_col0 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_fd835_row2_col2 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_fd835_row3_col1 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# </style>
# <table id="T_fd835">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_severity</th>
#       <th id="T_fd835_level0_col0" class="col_heading level0 col0" >Major Damage</th>
#       <th id="T_fd835_level0_col1" class="col_heading level0 col1" >Minor Damage</th>
#       <th id="T_fd835_level0_col2" class="col_heading level0 col2" >Total Loss</th>
#       <th id="T_fd835_level0_col3" class="col_heading level0 col3" >Trivial Damage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >incident_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd835_level0_row0" class="row_heading level0 row0" >Multi-vehicle Collision</th>
#       <td id="T_fd835_row0_col0" class="data row0 col0" >144</td>
#       <td id="T_fd835_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_fd835_row0_col2" class="data row0 col2" >145</td>
#       <td id="T_fd835_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fd835_level0_row1" class="row_heading level0 row1" >Parked Car</th>
#       <td id="T_fd835_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_fd835_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_fd835_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_fd835_row1_col3" class="data row1 col3" >42</td>
#     </tr>
#     <tr>
#       <th id="T_fd835_level0_row2" class="row_heading level0 row2" >Single Vehicle Collision</th>
#       <td id="T_fd835_row2_col0" class="data row2 col0" >132</td>
#       <td id="T_fd835_row2_col1" class="data row2 col1" >136</td>
#       <td id="T_fd835_row2_col2" class="data row2 col2" >135</td>
#       <td id="T_fd835_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fd835_level0_row3" class="row_heading level0 row3" >Vehicle Theft</th>
#       <td id="T_fd835_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_fd835_row3_col1" class="data row3 col1" >46</td>
#       <td id="T_fd835_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_fd835_row3_col3" class="data row3 col3" >48</td>
#     </tr>
#   </tbody>
# </table>

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('summer_r')
table = pd.crosstab(df['incident_type'], df['incident_severity'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar')
plt.title(' Incident Type VS incident_severity',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_hobbies insured_relationship  capital-gains  \
# 0       craft-repair        sleeping              husband          53300
# 1  machine-op-inspct         reading       other-relative              0
# 2              sales     board-games            own-child          35100
# 3       armed-forces     board-games            unmarried          48900
# 4              sales     board-games            unmarried          66000
#
#    capital-loss             incident_type   collision_type incident_severity  \
# 0             0  Single Vehicle Collision   Side Collision      Major Damage
# 1             0             Vehicle Theft   Rear Collision      Minor Damage
# 2             0   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3        -62400  Single Vehicle Collision  Front Collision      Major Damage
# 4        -46000             Vehicle Theft   Rear Collision      Minor Damage
#
#   authorities_contacted incident_state incident_city  \
# 0                Police             SC      Columbus
# 1                Police             VA     Riverwood
# 2                Police             NY      Columbus
# 3                Police             OH     Arlington
# 4                  None             NY     Arlington
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1              NO
# 2                         7                            3              NO
# 3                         5                            1              NO
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                      NO                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#   fraud_reported CSL_Personal CSL_Accidental  policy_bind_day  \
# 0              Y          250            500               17
# 1              Y          250            500               27
# 2              N          100            300                9
# 3              Y          250            500               25
# 4              N          500           1000                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age age_bins
# 0              11    41-50
# 1               8    41-50
# 2               8    21-30
# 3               1    41-50
# 4               6    41-50

# %%
Category = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 
            'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               2                  0                      4               4
# 1               1                  1                      4               5
# 2               1                  1                      4               1
# 3               0                  0                      4               2
# 4               1                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                1                1          2                        1
# 1                0                0          0                        0
# 2                0                2          3                        0
# 3                0                1          2                        0
# 4                0                0          1                        0
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age age_bins
# 0              11    41-50
# 1               8    41-50
# 2               8    21-30
# 3               1    41-50
# 4               6    41-50

# %%
# outliers detection and removal

Numerical = ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 
             'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age','policy_annual_premium']

# %%
len(Numerical)
# Out:
# 21

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column],color='blue')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#skweness of the feature

plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df[Numerical].skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_deductable              0.477887
# umbrella_limit                 1.806712
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# policy_bind_day                0.024372
# policy_bind_month             -0.029321
# policy_bind_year               0.052511
# incident_day                   0.059111
# incident_month                 1.375894
# Automobile_Age                 0.048289
# policy_annual_premium          0.004402
# dtype: float64

# %%
# Making the skew less than or equal to +0.5 and -0.5 for better prediction using yeo-johnson method
skew=['total_claim_amount','vehicle_claim']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[skew] = scaler.fit_transform(df[skew].values)

# %%
#checking skewness after transformation

df[skew].skew()
# Out:
# total_claim_amount   -0.510354
# vehicle_claim        -0.522718
# dtype: float64

# %%
#correlation

df.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922098     -0.000328
# age                                    0.922098  1.000000     -0.014533
# policy_state                          -0.000328 -0.014533      1.000000
# policy_deductable                      0.026807  0.029188      0.010033
# policy_annual_premium                  0.005018  0.014404      0.012455
# umbrella_limit                         0.015498  0.018126     -0.029580
# insured_sex                            0.060925  0.073337     -0.020481
# insured_education_level               -0.000833  0.000969     -0.034327
# insured_occupation                     0.009814  0.017220     -0.031215
# insured_hobbies                       -0.093661 -0.081315     -0.038689
# insured_relationship                   0.069727  0.074832     -0.018506
# capital-gains                          0.006399 -0.007075      0.074551
# capital-loss                           0.020209  0.007368     -0.030338
# incident_type                         -0.017377 -0.025626      0.031848
# collision_type                        -0.072787 -0.075642      0.052438
# incident_severity                     -0.059581 -0.058439     -0.026377
# authorities_contacted                  0.010021  0.015417     -0.016777
# incident_state                         0.005369  0.005770      0.008723
# incident_city                         -0.000130 -0.002291     -0.002077
# incident_hour_of_the_day               0.070639  0.087161      0.029457
# number_of_vehicles_involved            0.014736  0.022102     -0.042263
# property_damage                        0.005488 -0.003408     -0.008465
# bodily_injuries                       -0.010162 -0.015679      0.013384
# witnesses                              0.058383  0.052359      0.022960
# police_report_available               -0.022146 -0.020441      0.069017
# total_claim_amount                     0.062495  0.070386     -0.006305
# injury_claim                           0.065329  0.075522     -0.046290
# property_claim                         0.034940  0.060898      0.008406
# vehicle_claim                          0.061308  0.062764      0.001464
# auto_make                              0.047655  0.030410      0.017124
# auto_model                             0.004202  0.017343     -0.025253
# fraud_reported                         0.020544  0.012143      0.029432
# CSL_Personal                          -0.026819 -0.015185      0.001027
# CSL_Accidental                         0.008876  0.009876      0.028838
# policy_bind_day                        0.051728  0.053869      0.002277
# policy_bind_month                      0.005750  0.015501      0.071450
# policy_bind_year                      -0.048276 -0.037444     -0.007276
# incident_day                          -0.011092 -0.006131      0.014745
# incident_month                         0.024659  0.023404      0.023643
# Automobile_Age                         0.000292 -0.001354     -0.002114
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.026807               0.005018
# age                                   0.029188               0.014404
# policy_state                          0.010033               0.012455
# policy_deductable                     1.000000              -0.003245
# policy_annual_premium                -0.003245               1.000000
# umbrella_limit                        0.010870              -0.006247
# insured_sex                          -0.009733               0.038853
# insured_education_level               0.015217              -0.019715
# insured_occupation                   -0.046733               0.035922
# insured_hobbies                       0.004061              -0.018019
# insured_relationship                 -0.022945               0.001925
# capital-gains                         0.035212              -0.013738
# capital-loss                         -0.023544               0.023547
# incident_type                        -0.038411               0.053603
# collision_type                       -0.053912               0.036556
# incident_severity                    -0.015711              -0.011155
# authorities_contacted                -0.000760              -0.055191
# incident_state                        0.006517               0.046434
# incident_city                        -0.045117               0.048724
# incident_hour_of_the_day              0.060935              -0.001578
# number_of_vehicles_involved           0.051214              -0.045991
# property_damage                       0.015770               0.080738
# bodily_injuries                      -0.022765               0.026780
# witnesses                             0.066639               0.002332
# police_report_available               0.038036               0.021998
# total_claim_amount                    0.023350               0.008400
# injury_claim                          0.039107              -0.017633
# property_claim                        0.064792              -0.011654
# vehicle_claim                         0.004875               0.020028
# auto_make                            -0.035379               0.000045
# auto_model                           -0.003268              -0.031849
# fraud_reported                        0.014817              -0.014480
# CSL_Personal                          0.003384               0.023978
# CSL_Accidental                       -0.003931               0.003813
# policy_bind_day                       0.009164              -0.025183
# policy_bind_month                    -0.050416              -0.035355
# policy_bind_year                     -0.049598               0.001249
# incident_day                         -0.018160               0.014835
# incident_month                       -0.006418               0.021559
# Automobile_Age                       -0.026105               0.049226
#
#                              umbrella_limit  insured_sex  \
# months_as_customer                 0.015498     0.060925
# age                                0.018126     0.073337
# policy_state                      -0.029580    -0.020481
# policy_deductable                  0.010870    -0.009733
# policy_annual_premium             -0.006247     0.038853
# umbrella_limit                     1.000000     0.010688
# insured_sex                        0.010688     1.000000
# insured_education_level           -0.019357     0.009002
# insured_occupation                 0.023422    -0.006160
# insured_hobbies                   -0.037000    -0.020317
# insured_relationship               0.077495     0.002855
# capital-gains                     -0.047268    -0.020494
# capital-loss                      -0.024056    -0.021705
# incident_type                      0.015966     0.009952
# collision_type                     0.010041    -0.014293
# incident_severity                  0.009466    -0.028168
# authorities_contacted              0.029044     0.017914
# incident_state                    -0.077492    -0.022379
# incident_city                      0.013094     0.014470
# incident_hour_of_the_day          -0.023257     0.019290
# number_of_vehicles_involved       -0.021270     0.018793
# property_damage                   -0.076358     0.026969
# bodily_injuries                    0.022743    -0.020297
# witnesses                         -0.006738     0.042463
# police_report_available           -0.044771     0.006992
# total_claim_amount                -0.040182    -0.024532
# injury_claim                      -0.045412     0.000924
# property_claim                    -0.023790    -0.014868
# vehicle_claim                     -0.038275    -0.030626
# auto_make                         -0.004443     0.026457
# auto_model                         0.040256    -0.018421
# fraud_reported                     0.058622     0.030873
# CSL_Personal                       0.021636    -0.010757
# CSL_Accidental                     0.015602     0.070700
# policy_bind_day                   -0.045207     0.040713
# policy_bind_month                  0.009961    -0.004033
# policy_bind_year                   0.048008    -0.032891
# incident_day                      -0.021716    -0.007280
# incident_month                     0.042409     0.024227
# Automobile_Age                    -0.009893     0.028247
#
#                              insured_education_level  insured_occupation  \
# months_as_customer                         -0.000833            0.009814
# age                                         0.000969            0.017220
# policy_state                               -0.034327           -0.031215
# policy_deductable                           0.015217           -0.046733
# policy_annual_premium                      -0.019715            0.035922
# umbrella_limit                             -0.019357            0.023422
# insured_sex                                 0.009002           -0.006160
# insured_education_level                     1.000000           -0.020298
# insured_occupation                         -0.020298            1.000000
# insured_hobbies                             0.021807           -0.011077
# insured_relationship                       -0.023488           -0.010171
# capital-gains                               0.039912           -0.007824
# capital-loss                                0.041193           -0.020171
# incident_type                               0.013704            0.003842
# collision_type                             -0.019230            0.007401
# incident_severity                          -0.006420            0.004731
# authorities_contacted                      -0.010838           -0.007811
# incident_state                             -0.005903           -0.022761
# incident_city                              -0.018636            0.000390
# incident_hour_of_the_day                   -0.057061           -0.018435
# number_of_vehicles_involved                -0.003768           -0.015368
# property_damage                            -0.048909           -0.016378
# bodily_injuries                            -0.012072           -0.000236
# witnesses                                   0.019211           -0.014794
# police_report_available                     0.051640           -0.025232
# total_claim_amount                          0.074466            0.003703
# injury_claim                                0.081880            0.020211
# property_claim                              0.055794            0.003004
# vehicle_claim                               0.068308           -0.000852
# auto_make                                   0.055202            0.042621
# auto_model                                  0.049445            0.020584
# fraud_reported                              0.008808            0.001564
# CSL_Personal                                0.009153            0.015788
# CSL_Accidental                             -0.006546           -0.003804
# policy_bind_day                             0.012610           -0.006432
# policy_bind_month                          -0.007118            0.026140
# policy_bind_year                            0.018952           -0.027085
# incident_day                               -0.058104           -0.022105
# incident_month                              0.075083            0.019403
# Automobile_Age                             -0.043509            0.006676
#
#                              insured_hobbies  insured_relationship  \
# months_as_customer                 -0.093661              0.069727
# age                                -0.081315              0.074832
# policy_state                       -0.038689             -0.018506
# policy_deductable                   0.004061             -0.022945
# policy_annual_premium              -0.018019              0.001925
# umbrella_limit                     -0.037000              0.077495
# insured_sex                        -0.020317              0.002855
# insured_education_level             0.021807             -0.023488
# insured_occupation                 -0.011077             -0.010171
# insured_hobbies                     1.000000             -0.096772
# insured_relationship               -0.096772              1.000000
# capital-gains                       0.054338             -0.019439
# capital-loss                       -0.031811             -0.064453
# incident_type                       0.007711              0.033834
# collision_type                      0.016700             -0.005850
# incident_severity                  -0.024688              0.015498
# authorities_contacted              -0.028104             -0.004070
# incident_state                      0.085764             -0.062331
# incident_city                       0.018542             -0.002288
# incident_hour_of_the_day            0.019979              0.004805
# number_of_vehicles_involved         0.012586             -0.047354
# property_damage                     0.036193             -0.031931
# bodily_injuries                     0.031373             -0.001214
# witnesses                          -0.033971              0.002362
# police_report_available            -0.027937             -0.017471
# total_claim_amount                 -0.002978              0.003005
# injury_claim                        0.028393              0.029014
# property_claim                      0.012535              0.007332
# vehicle_claim                      -0.015568             -0.005663
# auto_make                           0.001525             -0.027028
# auto_model                          0.030948              0.063671
# fraud_reported                     -0.046838              0.021043
# CSL_Personal                       -0.005960             -0.030063
# CSL_Accidental                      0.036946             -0.043769
# policy_bind_day                     0.028914              0.010135
# policy_bind_month                  -0.004922              0.040811
# policy_bind_year                   -0.013986             -0.006494
# incident_day                        0.014893             -0.080738
# incident_month                     -0.000082              0.045927
# Automobile_Age                      0.014495              0.023345
#
#                              capital-gains  capital-loss  incident_type  \
# months_as_customer                0.006399      0.020209      -0.017377
# age                              -0.007075      0.007368      -0.025626
# policy_state                      0.074551     -0.030338       0.031848
# policy_deductable                 0.035212     -0.023544      -0.038411
# policy_annual_premium            -0.013738      0.023547       0.053603
# umbrella_limit                   -0.047268     -0.024056       0.015966
# insured_sex                      -0.020494     -0.021705       0.009952
# insured_education_level           0.039912      0.041193       0.013704
# insured_occupation               -0.007824     -0.020171       0.003842
# insured_hobbies                   0.054338     -0.031811       0.007711
# insured_relationship             -0.019439     -0.064453       0.033834
# capital-gains                     1.000000     -0.046904      -0.045857
# capital-loss                     -0.046904      1.000000       0.026101
# incident_type                    -0.045857      0.026101       1.000000
# collision_type                   -0.006170      0.041494      -0.070920
# incident_severity                -0.013396     -0.018647       0.159915
# authorities_contacted            -0.044892      0.025192       0.100450
# incident_state                    0.013833     -0.048651       0.037083
# incident_city                    -0.024989     -0.038092       0.022117
# incident_hour_of_the_day         -0.016406     -0.025054      -0.133387
# number_of_vehicles_involved       0.061643     -0.014895      -0.893274
# property_damage                  -0.000616      0.016981       0.020263
# bodily_injuries                   0.055829     -0.024418      -0.009733
# witnesses                        -0.017651     -0.041330      -0.007299
# police_report_available          -0.012939     -0.039256       0.019917
# total_claim_amount                0.015210     -0.036694      -0.270055
# injury_claim                      0.025934     -0.046060      -0.226704
# property_claim                   -0.000779     -0.022863      -0.221409
# vehicle_claim                     0.014891     -0.033303      -0.263485
# auto_make                         0.052014     -0.041658      -0.032784
# auto_model                        0.036569     -0.037288      -0.034302
# fraud_reported                   -0.019173     -0.014863      -0.050376
# CSL_Personal                      0.005249     -0.034612       0.011997
# CSL_Accidental                    0.001635      0.008063      -0.006631
# policy_bind_day                   0.007994     -0.038297      -0.008791
# policy_bind_month                -0.011102      0.003436       0.035982
# policy_bind_year                  0.041249     -0.026420      -0.049407
# incident_day                      0.015418     -0.015035       0.013166
# incident_month                    0.029409      0.023216      -0.039270
# Automobile_Age                   -0.031398      0.056615       0.053191
#
#                              collision_type  incident_severity  \
# months_as_customer                -0.072787          -0.059581
# age                               -0.075642          -0.058439
# policy_state                       0.052438          -0.026377
# policy_deductable                 -0.053912          -0.015711
# policy_annual_premium              0.036556          -0.011155
# umbrella_limit                     0.010041           0.009466
# insured_sex                       -0.014293          -0.028168
# insured_education_level           -0.019230          -0.006420
# insured_occupation                 0.007401           0.004731
# insured_hobbies                    0.016700          -0.024688
# insured_relationship              -0.005850           0.015498
# capital-gains                     -0.006170          -0.013396
# capital-loss                       0.041494          -0.018647
# incident_type                     -0.070920           0.159915
# collision_type                     1.000000          -0.014702
# incident_severity                 -0.014702           1.000000
# authorities_contacted              0.062212           0.164966
# incident_state                     0.031680           0.060019
# incident_city                      0.032114          -0.016541
# incident_hour_of_the_day           0.044074          -0.071946
# number_of_vehicles_involved        0.078999          -0.168719
# property_damage                    0.004059          -0.036102
# bodily_injuries                   -0.018146          -0.018870
# witnesses                         -0.046659          -0.011127
# police_report_available            0.047648           0.002808
# total_claim_amount                -0.012729          -0.360100
# injury_claim                      -0.024996          -0.276980
# property_claim                    -0.003844          -0.301861
# vehicle_claim                     -0.010023          -0.355943
# auto_make                         -0.007501          -0.008571
# auto_model                         0.024323          -0.046442
# fraud_reported                    -0.017315          -0.405988
# CSL_Personal                       0.020641           0.022530
# CSL_Accidental                    -0.017275           0.003459
# policy_bind_day                    0.018820          -0.041216
# policy_bind_month                 -0.039847          -0.032932
# policy_bind_year                   0.026098           0.004322
# incident_day                       0.047285           0.017906
# incident_month                    -0.026419          -0.007442
# Automobile_Age                     0.001204           0.019646
#
#                              authorities_contacted  incident_state  \
# months_as_customer                        0.010021        0.005369
# age                                       0.015417        0.005770
# policy_state                             -0.016777        0.008723
# policy_deductable                        -0.000760        0.006517
# policy_annual_premium                    -0.055191        0.046434
# umbrella_limit                            0.029044       -0.077492
# insured_sex                               0.017914       -0.022379
# insured_education_level                  -0.010838       -0.005903
# insured_occupation                       -0.007811       -0.022761
# insured_hobbies                          -0.028104        0.085764
# insured_relationship                     -0.004070       -0.062331
# capital-gains                            -0.044892        0.013833
# capital-loss                              0.025192       -0.048651
# incident_type                             0.100450        0.037083
# collision_type                            0.062212        0.031680
# incident_severity                         0.164966        0.060019
# authorities_contacted                     1.000000        0.026542
# incident_state                            0.026542        1.000000
# incident_city                            -0.003299        0.014588
# incident_hour_of_the_day                 -0.060955       -0.036525
# number_of_vehicles_involved              -0.081508       -0.037384
# property_damage                          -0.004884       -0.045569
# bodily_injuries                           0.041692       -0.000036
# witnesses                                -0.003721        0.012177
# police_report_available                   0.044407        0.045007
# total_claim_amount                       -0.164698       -0.042156
# injury_claim                             -0.141826       -0.015826
# property_claim                           -0.118808       -0.026930
# vehicle_claim                            -0.164419       -0.048887
# auto_make                                -0.030309        0.070178
# auto_model                                0.017536       -0.039857
# fraud_reported                           -0.045802       -0.051407
# CSL_Personal                              0.056182        0.032814
# CSL_Accidental                            0.002825        0.004413
# policy_bind_day                          -0.034609        0.035967
# policy_bind_month                        -0.053040        0.004206
# policy_bind_year                         -0.027683       -0.025369
# incident_day                             -0.013077        0.017280
# incident_month                            0.004593       -0.025579
# Automobile_Age                           -0.072524        0.014658
#
#                              incident_city  incident_hour_of_the_day  \
# months_as_customer               -0.000130                  0.070639
# age                              -0.002291                  0.087161
# policy_state                     -0.002077                  0.029457
# policy_deductable                -0.045117                  0.060935
# policy_annual_premium             0.048724                 -0.001578
# umbrella_limit                    0.013094                 -0.023257
# insured_sex                       0.014470                  0.019290
# insured_education_level          -0.018636                 -0.057061
# insured_occupation                0.000390                 -0.018435
# insured_hobbies                   0.018542                  0.019979
# insured_relationship             -0.002288                  0.004805
# capital-gains                    -0.024989                 -0.016406
# capital-loss                     -0.038092                 -0.025054
# incident_type                     0.022117                 -0.133387
# collision_type                    0.032114                  0.044074
# incident_severity                -0.016541                 -0.071946
# authorities_contacted            -0.003299                 -0.060955
# incident_state                    0.014588                 -0.036525
# incident_city                     1.000000                  0.017039
# incident_hour_of_the_day          0.017039                  1.000000
# number_of_vehicles_involved      -0.009840                  0.120794
# property_damage                   0.009879                  0.064425
# bodily_injuries                   0.051782                 -0.034563
# witnesses                         0.009058                  0.006527
# police_report_available           0.010203                  0.040558
# total_claim_amount                0.042821                  0.214318
# injury_claim                      0.045794                  0.165768
# property_claim                    0.041101                  0.179536
# vehicle_claim                     0.037016                  0.211365
# auto_make                        -0.002237                 -0.002556
# auto_model                        0.015118                 -0.058342
# fraud_reported                   -0.040403                  0.004316
# CSL_Personal                      0.009333                 -0.001869
# CSL_Accidental                   -0.025689                  0.005211
# policy_bind_day                   0.020263                 -0.009511
# policy_bind_month                 0.067565                 -0.000934
# policy_bind_year                 -0.010343                  0.035412
# incident_day                     -0.050927                 -0.027965
# incident_month                    0.034799                  0.044827
# Automobile_Age                   -0.058645                 -0.021368
#
#                              number_of_vehicles_involved  property_damage  \
# months_as_customer                              0.014736         0.005488
# age                                             0.022102        -0.003408
# policy_state                                   -0.042263        -0.008465
# policy_deductable                               0.051214         0.015770
# policy_annual_premium                          -0.045991         0.080738
# umbrella_limit                                 -0.021270        -0.076358
# insured_sex                                     0.018793         0.026969
# insured_education_level                        -0.003768        -0.048909
# insured_occupation                             -0.015368        -0.016378
# insured_hobbies                                 0.012586         0.036193
# insured_relationship                           -0.047354        -0.031931
# capital-gains                                   0.061643        -0.000616
# capital-loss                                   -0.014895         0.016981
# incident_type                                  -0.893274         0.020263
# collision_type                                  0.078999         0.004059
# incident_severity                              -0.168719        -0.036102
# authorities_contacted                          -0.081508        -0.004884
# incident_state                                 -0.037384        -0.045569
# incident_city                                  -0.009840         0.009879
# incident_hour_of_the_day                        0.120794         0.064425
# number_of_vehicles_involved                     1.000000        -0.013641
# property_damage                                -0.013641         1.000000
# bodily_injuries                                 0.014030         0.003762
# witnesses                                      -0.014669        -0.019753
# police_report_available                        -0.007291        -0.022657
# total_claim_amount                              0.267331         0.061744
# injury_claim                                    0.224650         0.048886
# property_claim                                  0.219084         0.045211
# vehicle_claim                                   0.260793         0.062087
# auto_make                                       0.014343        -0.010203
# auto_model                                      0.032219        -0.051472
# fraud_reported                                  0.051839         0.017202
# CSL_Personal                                   -0.019403        -0.027634
# CSL_Accidental                                  0.005135         0.009732
# policy_bind_day                                 0.005787        -0.012384
# policy_bind_month                              -0.044608         0.008469
# policy_bind_year                                0.026595         0.017939
# incident_day                                   -0.018672         0.009313
# incident_month                                  0.032544         0.004713
# Automobile_Age                                 -0.034554         0.037711
#
#                              bodily_injuries  witnesses  \
# months_as_customer                 -0.010162   0.058383
# age                                -0.015679   0.052359
# policy_state                        0.013384   0.022960
# policy_deductable                  -0.022765   0.066639
# policy_annual_premium               0.026780   0.002332
# umbrella_limit                      0.022743  -0.006738
# insured_sex                        -0.020297   0.042463
# insured_education_level            -0.012072   0.019211
# insured_occupation                 -0.000236  -0.014794
# insured_hobbies                     0.031373  -0.033971
# insured_relationship               -0.001214   0.002362
# capital-gains                       0.055829  -0.017651
# capital-loss                       -0.024418  -0.041330
# incident_type                      -0.009733  -0.007299
# collision_type                     -0.018146  -0.046659
# incident_severity                  -0.018870  -0.011127
# authorities_contacted               0.041692  -0.003721
# incident_state                     -0.000036   0.012177
# incident_city                       0.051782   0.009058
# incident_hour_of_the_day           -0.034563   0.006527
# number_of_vehicles_involved         0.014030  -0.014669
# property_damage                     0.003762  -0.019753
# bodily_injuries                     1.000000  -0.005606
# witnesses                          -0.005606   1.000000
# police_report_available             0.011860   0.048653
# total_claim_amount                  0.048629  -0.011124
# injury_claim                        0.047319  -0.024843
# property_claim                      0.039749   0.052640
# vehicle_claim                       0.045074  -0.023260
# auto_make                           0.026731   0.005603
# auto_model                          0.020007  -0.011232
# fraud_reported                      0.033877   0.049497
# CSL_Personal                       -0.000595   0.071500
# CSL_Accidental                     -0.016047  -0.012116
# policy_bind_day                    -0.043500   0.005071
# policy_bind_month                  -0.031138  -0.015996
# policy_bind_year                    0.029987   0.055907
# incident_day                       -0.032062   0.013118
# incident_month                      0.047035  -0.029749
# Automobile_Age                      0.020527  -0.045791
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                         -0.022146            0.062495
# age                                        -0.020441            0.070386
# policy_state                                0.069017           -0.006305
# policy_deductable                           0.038036            0.023350
# policy_annual_premium                       0.021998            0.008400
# umbrella_limit                             -0.044771           -0.040182
# insured_sex                                 0.006992           -0.024532
# insured_education_level                     0.051640            0.074466
# insured_occupation                         -0.025232            0.003703
# insured_hobbies                            -0.027937           -0.002978
# insured_relationship                       -0.017471            0.003005
# capital-gains                              -0.012939            0.015210
# capital-loss                               -0.039256           -0.036694
# incident_type                               0.019917           -0.270055
# collision_type                              0.047648           -0.012729
# incident_severity                           0.002808           -0.360100
# authorities_contacted                       0.044407           -0.164698
# incident_state                              0.045007           -0.042156
# incident_city                               0.010203            0.042821
# incident_hour_of_the_day                    0.040558            0.214318
# number_of_vehicles_involved                -0.007291            0.267331
# property_damage                            -0.022657            0.061744
# bodily_injuries                             0.011860            0.048629
# witnesses                                   0.048653           -0.011124
# police_report_available                     1.000000            0.035921
# total_claim_amount                          0.035921            1.000000
# injury_claim                                0.028211            0.806392
# property_claim                              0.012423            0.812322
# vehicle_claim                               0.040122            0.981220
# auto_make                                   0.068149           -0.058804
# auto_model                                 -0.017974            0.040885
# fraud_reported                             -0.027768            0.161867
# CSL_Personal                               -0.001645           -0.054800
# CSL_Accidental                              0.056154           -0.012461
# policy_bind_day                            -0.027201           -0.001270
# policy_bind_month                           0.011106            0.056660
# policy_bind_year                           -0.011907           -0.001780
# incident_day                                0.029234           -0.048968
# incident_month                             -0.024870            0.061953
# Automobile_Age                              0.022339            0.035796
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer               0.065329        0.034940       0.061308
# age                              0.075522        0.060898       0.062764
# policy_state                    -0.046290        0.008406       0.001464
# policy_deductable                0.039107        0.064792       0.004875
# policy_annual_premium           -0.017633       -0.011654       0.020028
# umbrella_limit                  -0.045412       -0.023790      -0.038275
# insured_sex                      0.000924       -0.014868      -0.030626
# insured_education_level          0.081880        0.055794       0.068308
# insured_occupation               0.020211        0.003004      -0.000852
# insured_hobbies                  0.028393        0.012535      -0.015568
# insured_relationship             0.029014        0.007332      -0.005663
# capital-gains                    0.025934       -0.000779       0.014891
# capital-loss                    -0.046060       -0.022863      -0.033303
# incident_type                   -0.226704       -0.221409      -0.263485
# collision_type                  -0.024996       -0.003844      -0.010023
# incident_severity               -0.276980       -0.301861      -0.355943
# authorities_contacted           -0.141826       -0.118808      -0.164419
# incident_state                  -0.015826       -0.026930      -0.048887
# incident_city                    0.045794        0.041101       0.037016
# incident_hour_of_the_day         0.165768        0.179536       0.211365
# number_of_vehicles_involved      0.224650        0.219084       0.260793
# property_damage                  0.048886        0.045211       0.062087
# bodily_injuries                  0.047319        0.039749       0.045074
# witnesses                       -0.024843        0.052640      -0.023260
# police_report_available          0.028211        0.012423       0.040122
# total_claim_amount               0.806392        0.812322       0.981220
# injury_claim                     1.000000        0.563866       0.720711
# property_claim                   0.563866        1.000000       0.730292
# vehicle_claim                    0.720711        0.730292       1.000000
# auto_make                       -0.039575       -0.042030      -0.060922
# auto_model                       0.038136        0.048857       0.034628
# fraud_reported                   0.090975        0.137835       0.168249
# CSL_Personal                    -0.078818       -0.042216      -0.045278
# CSL_Accidental                   0.007745       -0.013888      -0.015989
# policy_bind_day                  0.015576       -0.003849      -0.004994
# policy_bind_month                0.014858        0.054255       0.061709
# policy_bind_year                 0.002529       -0.000970      -0.002760
# incident_day                    -0.029935       -0.024240      -0.054870
# incident_month                   0.021624        0.042763       0.070710
# Automobile_Age                   0.013718        0.014508       0.042947
#
#                              auto_make  auto_model  fraud_reported  \
# months_as_customer            0.047655    0.004202        0.020544
# age                           0.030410    0.017343        0.012143
# policy_state                  0.017124   -0.025253        0.029432
# policy_deductable            -0.035379   -0.003268        0.014817
# policy_annual_premium         0.000045   -0.031849       -0.014480
# umbrella_limit               -0.004443    0.040256        0.058622
# insured_sex                   0.026457   -0.018421        0.030873
# insured_education_level       0.055202    0.049445        0.008808
# insured_occupation            0.042621    0.020584        0.001564
# insured_hobbies               0.001525    0.030948       -0.046838
# insured_relationship         -0.027028    0.063671        0.021043
# capital-gains                 0.052014    0.036569       -0.019173
# capital-loss                 -0.041658   -0.037288       -0.014863
# incident_type                -0.032784   -0.034302       -0.050376
# collision_type               -0.007501    0.024323       -0.017315
# incident_severity            -0.008571   -0.046442       -0.405988
# authorities_contacted        -0.030309    0.017536       -0.045802
# incident_state                0.070178   -0.039857       -0.051407
# incident_city                -0.002237    0.015118       -0.040403
# incident_hour_of_the_day     -0.002556   -0.058342        0.004316
# number_of_vehicles_involved   0.014343    0.032219        0.051839
# property_damage              -0.010203   -0.051472        0.017202
# bodily_injuries               0.026731    0.020007        0.033877
# witnesses                     0.005603   -0.011232        0.049497
# police_report_available       0.068149   -0.017974       -0.027768
# total_claim_amount           -0.058804    0.040885        0.161867
# injury_claim                 -0.039575    0.038136        0.090975
# property_claim               -0.042030    0.048857        0.137835
# vehicle_claim                -0.060922    0.034628        0.168249
# auto_make                     1.000000   -0.166295       -0.027519
# auto_model                   -0.166295    1.000000        0.000720
# fraud_reported               -0.027519    0.000720        1.000000
# CSL_Personal                 -0.004701    0.047885       -0.037190
# CSL_Accidental               -0.032594   -0.007946        0.041475
# policy_bind_day              -0.015631   -0.010700        0.060643
# policy_bind_month            -0.041342   -0.004393       -0.030829
# policy_bind_year             -0.004779    0.026988       -0.000059
# incident_day                  0.057635   -0.040702       -0.044151
# incident_month               -0.041513    0.033487        0.014495
# Automobile_Age               -0.004939   -0.032831       -0.007928
#
#                              CSL_Personal  CSL_Accidental  policy_bind_day  \
# months_as_customer              -0.026819        0.008876         0.051728
# age                             -0.015185        0.009876         0.053869
# policy_state                     0.001027        0.028838         0.002277
# policy_deductable                0.003384       -0.003931         0.009164
# policy_annual_premium            0.023978        0.003813        -0.025183
# umbrella_limit                   0.021636        0.015602        -0.045207
# insured_sex                     -0.010757        0.070700         0.040713
# insured_education_level          0.009153       -0.006546         0.012610
# insured_occupation               0.015788       -0.003804        -0.006432
# insured_hobbies                 -0.005960        0.036946         0.028914
# insured_relationship            -0.030063       -0.043769         0.010135
# capital-gains                    0.005249        0.001635         0.007994
# capital-loss                    -0.034612        0.008063        -0.038297
# incident_type                    0.011997       -0.006631        -0.008791
# collision_type                   0.020641       -0.017275         0.018820
# incident_severity                0.022530        0.003459        -0.041216
# authorities_contacted            0.056182        0.002825        -0.034609
# incident_state                   0.032814        0.004413         0.035967
# incident_city                    0.009333       -0.025689         0.020263
# incident_hour_of_the_day        -0.001869        0.005211        -0.009511
# number_of_vehicles_involved     -0.019403        0.005135         0.005787
# property_damage                 -0.027634        0.009732        -0.012384
# bodily_injuries                 -0.000595       -0.016047        -0.043500
# witnesses                        0.071500       -0.012116         0.005071
# police_report_available         -0.001645        0.056154        -0.027201
# total_claim_amount              -0.054800       -0.012461        -0.001270
# injury_claim                    -0.078818        0.007745         0.015576
# property_claim                  -0.042216       -0.013888        -0.003849
# vehicle_claim                   -0.045278       -0.015989        -0.004994
# auto_make                       -0.004701       -0.032594        -0.015631
# auto_model                       0.047885       -0.007946        -0.010700
# fraud_reported                  -0.037190        0.041475         0.060643
# CSL_Personal                     1.000000       -0.459462         0.018973
# CSL_Accidental                  -0.459462        1.000000         0.011112
# policy_bind_day                  0.018973        0.011112         1.000000
# policy_bind_month               -0.045345        0.031318         0.031699
# policy_bind_year                -0.016466        0.002903         0.000221
# incident_day                    -0.004156        0.022334         0.022012
# incident_month                  -0.011794       -0.023041         0.004511
# Automobile_Age                   0.033082       -0.033820        -0.025360
#
#                              policy_bind_month  policy_bind_year  \
# months_as_customer                    0.005750         -0.048276
# age                                   0.015501         -0.037444
# policy_state                          0.071450         -0.007276
# policy_deductable                    -0.050416         -0.049598
# policy_annual_premium                -0.035355          0.001249
# umbrella_limit                        0.009961          0.048008
# insured_sex                          -0.004033         -0.032891
# insured_education_level              -0.007118          0.018952
# insured_occupation                    0.026140         -0.027085
# insured_hobbies                      -0.004922         -0.013986
# insured_relationship                  0.040811         -0.006494
# capital-gains                        -0.011102          0.041249
# capital-loss                          0.003436         -0.026420
# incident_type                         0.035982         -0.049407
# collision_type                       -0.039847          0.026098
# incident_severity                    -0.032932          0.004322
# authorities_contacted                -0.053040         -0.027683
# incident_state                        0.004206         -0.025369
# incident_city                         0.067565         -0.010343
# incident_hour_of_the_day             -0.000934          0.035412
# number_of_vehicles_involved          -0.044608          0.026595
# property_damage                       0.008469          0.017939
# bodily_injuries                      -0.031138          0.029987
# witnesses                            -0.015996          0.055907
# police_report_available               0.011106         -0.011907
# total_claim_amount                    0.056660         -0.001780
# injury_claim                          0.014858          0.002529
# property_claim                        0.054255         -0.000970
# vehicle_claim                         0.061709         -0.002760
# auto_make                            -0.041342         -0.004779
# auto_model                           -0.004393          0.026988
# fraud_reported                       -0.030829         -0.000059
# CSL_Personal                         -0.045345         -0.016466
# CSL_Accidental                        0.031318          0.002903
# policy_bind_day                       0.031699          0.000221
# policy_bind_month                     1.000000         -0.010210
# policy_bind_year                     -0.010210          1.000000
# incident_day                         -0.041767          0.049555
# incident_month                        0.017970         -0.061635
# Automobile_Age                        0.002481         -0.015164
#
#                              incident_day  incident_month  Automobile_Age
# months_as_customer              -0.011092        0.024659        0.000292
# age                             -0.006131        0.023404       -0.001354
# policy_state                     0.014745        0.023643       -0.002114
# policy_deductable               -0.018160       -0.006418       -0.026105
# policy_annual_premium            0.014835        0.021559        0.049226
# umbrella_limit                  -0.021716        0.042409       -0.009893
# insured_sex                     -0.007280        0.024227        0.028247
# insured_education_level         -0.058104        0.075083       -0.043509
# insured_occupation              -0.022105        0.019403        0.006676
# insured_hobbies                  0.014893       -0.000082        0.014495
# insured_relationship            -0.080738        0.045927        0.023345
# capital-gains                    0.015418        0.029409       -0.031398
# capital-loss                    -0.015035        0.023216        0.056615
# incident_type                    0.013166       -0.039270        0.053191
# collision_type                   0.047285       -0.026419        0.001204
# incident_severity                0.017906       -0.007442        0.019646
# authorities_contacted           -0.013077        0.004593       -0.072524
# incident_state                   0.017280       -0.025579        0.014658
# incident_city                   -0.050927        0.034799       -0.058645
# incident_hour_of_the_day        -0.027965        0.044827       -0.021368
# number_of_vehicles_involved     -0.018672        0.032544       -0.034554
# property_damage                  0.009313        0.004713        0.037711
# bodily_injuries                 -0.032062        0.047035        0.020527
# witnesses                        0.013118       -0.029749       -0.045791
# police_report_available          0.029234       -0.024870        0.022339
# total_claim_amount              -0.048968        0.061953        0.035796
# injury_claim                    -0.029935        0.021624        0.013718
# property_claim                  -0.024240        0.042763        0.014508
# vehicle_claim                   -0.054870        0.070710        0.042947
# auto_make                        0.057635       -0.041513       -0.004939
# auto_model                      -0.040702        0.033487       -0.032831
# fraud_reported                  -0.044151        0.014495       -0.007928
# CSL_Personal                    -0.004156       -0.011794        0.033082
# CSL_Accidental                   0.022334       -0.023041       -0.033820
# policy_bind_day                  0.022012        0.004511       -0.025360
# policy_bind_month               -0.041767        0.017970        0.002481
# policy_bind_year                 0.049555       -0.061635       -0.015164
# incident_day                     1.000000       -0.666464       -0.016178
# incident_month                  -0.666464        1.000000        0.034734
# Automobile_Age                  -0.016178        0.034734        1.000000

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', cmap="gist_stern")
plt.show()

# %%
plt.figure(figsize=(22,10))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar',color='y')
plt.xlabel('Feature',fontsize=14,fontweight='bold')
plt.ylabel('Target',fontsize=14,fontweight='bold')
plt.title('Correlation of features with Target Variable Fraud_reported',fontsize=20,fontweight='bold')
plt.show()

# %%
#balamcing imbalanced target feature

df.fraud_reported.value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64
